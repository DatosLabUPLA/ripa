# %%
import pandas as pd
import numpy as np

# %%
gscholar_file = '../GSCHOLAR/DATA/autores.csv'
anid_file = '../Scraper ANID/DATA/investigadores.anid.csv'

df_gs = pd.read_csv(gscholar_file)
df_anid = pd.read_csv(anid_file)

# %%
df_gs.head()
# Out:
#                          Autor  \
# 0  Ezequiel Lagos Vasconcellos
# 1               Hans Zinnecker
# 2              Eugenio Uriarte
# 3             Vicente Martinez
# 4                 Nassir Sapag
#
#                                          Universidad  \
# 0                      Universidad Autónoma de Chile
# 1                      Universidad Autónoma de Chile
# 2  Profesor de Química Medicinal, Universidad de ...
# 3  Investigador Asociado Universidad Autónoma de ...
# 4                      Universidad Autónoma de Chile
#
#                                            Correo  \
# 0  Dirección de correo verificada de uautonoma.cl
# 1  Dirección de correo verificada de uautonoma.cl
# 2  Dirección de correo verificada de uautonoma.cl
# 3  Dirección de correo verificada de uautonoma.cl
# 4  Dirección de correo verificada de uautonoma.cl
#
#                                 Intereses        Cant Citas
# 0                                     NaN  Citado por 19048
# ...

# %%
df_anid.head()
# Out:
#                                   Name             Position  \
# 0                       Ezequiel Lagos                  NaN
# 1      Lunelia Sonia Betancour Sanchez                  NaN
# 2        Jaime Arturo Otazo Hermosilla                  NaN
# 3  Patricio Alejandro Rojas Montecinos  Assistant Professor
# 4        Patricio Rodrigo Orio Alvarez     Profesor Titular
#
#                          University              Place   Code
# 0        UNIVERSIDAD DE LA FRONTERA      Temuco, Chile  10000
# 1        UNIVERSIDAD DE LA FRONTERA      Temuco, Chile  10000
# 2        UNIVERSIDAD DE LA FRONTERA      Temuco, Chile  10001
# 3  UNIVERSIDAD DE SANTIAGO DE CHILE    Santiago, Chile  10002
# 4         UNIVERSIDAD DE VALPARAÍSO  Valparaíso, Chile  10003

# %%
merged_data = pd.merge(df_gs, df_anid, left_on=['Autor'], right_on=['Name'])
merged_data.head()
# Out:
#                   Autor                                        Universidad  \
# 0  Jimena Cuenca Moreno                           Universidad de los Andes
# 1       Marcelo Mendoza  Associate Professor, Universidad Técnica Feder...
# 2  Carlos Gonzalez Leon                          Universidad de Valparaiso
#
#                                         Correo  \
# 0  Dirección de correo verificada de uandes.cl
# 1     Dirección de correo verificada de usm.cl
# 2      Dirección de correo verificada de uv.cl
#
#                                            Intereses       Cant Citas  \
# 0  Cell therapy inflammation mesenchymal stem cells   Citado por 2481
# 1  Online social networks information retrieval s...  Citado por 6433
# 2                            Ion Channel Biophysics   Citado por 3313
#
#                    Name               Position  \
# 0  Jimena Cuenca Moreno  Investigador/profesor
# 1       Marcelo Mendoza      Profesor Asociado
# ...
